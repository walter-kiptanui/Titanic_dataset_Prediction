# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
titanic_df = pd.read_csv('D:/VOLUME E/DATA SCIENCE/INSIGHTS/Titanic Dataset/train.csv')
titanic_df.head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %%
titanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
titanic_df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# Exploratory Data analysis

# %%
titanic_df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#since the number of missing values for the cabin column is 687, we
# will drop the column

# %%
titanic_df = titanic_df.drop(columns = ['Cabin'])
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
#converting the sex into numerical values
to_map = {
    'male' : 1,
    'female' : 0
}
titanic_df['Sex'] = titanic_df['Sex'].replace(to_map)
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#              Ticket     Fare Embarked
# 0         A/5 21171   7.2500        S
# 1          PC 17599  71.2833        C
# 2  STON/O2. 3101282   7.9250        S
# 3            113803  53.1000        S
# 4            373450   8.0500        S

# %%
#Check for correlation between data in oder to know the columns that should
# be used to fill the age column missing values
corr_matrix = titanic_df.corr()

# %%
import seaborn as sns

# %%
plt.figure(figsize = (12,8))
sns.heatmap(corr_matrix, annot = True, cmap = 'inferno')
# Out:
# <AxesSubplot:>

# %%
#Fill the missing age by mean age of Pclass, Sex and survived
col = ['Survived', 'Pclass', 'Sex']
titanic_df['Age'] = titanic_df['Age'].fillna(titanic_df.groupby(col)['Age'].transform('mean'))
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#              Ticket     Fare Embarked
# 0         A/5 21171   7.2500        S
# 1          PC 17599  71.2833        C
# 2  STON/O2. 3101282   7.9250        S
# 3            113803  53.1000        S
# 4            373450   8.0500        S

# %%
titanic_df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       2
# dtype: int64

# %%
#filling the empty values of the embarked column
titanic_df['Embarked'].fillna(titanic_df['Embarked'].mode()[0], inplace = True)
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#              Ticket     Fare Embarked
# 0         A/5 21171   7.2500        S
# 1          PC 17599  71.2833        C
# 2  STON/O2. 3101282   7.9250        S
# 3            113803  53.1000        S
# 4            373450   8.0500        S

# %%
titanic_df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
#Check for duplicates
titanic_df.duplicated().sum()
# Out:
# 0

# %%
#The relationship between Pclass and Survived
plt.figure(figsize = (12, 8))
color_palette = sns.color_palette('magma')[0]
sns.barplot(x = 'Pclass', y = 'Survived', data = titanic_df, color = color_palette);

# %% [markdown]
# the people with Pclass of 1 had greater chances of surviving.

# %%
#The relationship between Sex and Survived
plt.figure(figsize = (12, 8))
color_palette = sns.color_palette('magma')[0]
sns.barplot(x = 'Sex', y = 'Survived', data = titanic_df, color = color_palette)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Survived'>

# %% [markdown]
# Most males died than females

# %%
#The relationship between Age and Survived
plt.figure(figsize = (12, 8))
color_palette = sns.color_palette('Blues')[0]
sns.barplot(x = 'Age', y = 'Survived', data = titanic_df, color = color_palette )
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Survived'>

# %%
titanic_df['Embarked'].nunique()
# Out:
# 3

# %%
mapping = {
    'S' : 1,
    'C' : 2,
    'Q' : 3
}
titanic_df['Embarked'] = titanic_df['Embarked'].replace(mapping)
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#              Ticket     Fare  Embarked
# 0         A/5 21171   7.2500         1
# 1          PC 17599  71.2833         2
# 2  STON/O2. 3101282   7.9250         1
# 3            113803  53.1000         1
# 4            373450   8.0500         1

# %%
#def frequency_encoder(Titanic_df, col):
 #   fe = Titanic_df.groupby(col).size()/len(Titanic_df)
#    Titanic_df[col+'_encoded'] = Titanic_df[col].map(fe)
#    return Titanic_df
#titanic_data = frequency_encoder(Titanic_df, 'Name')
#titanic_data = frequency_encoder(Titanic_df, 'Ticket')
#titanic_data.head(20)

# %%
#titanic_data['Ticket_1'] = pd.factorize(titanic_data.Ticket)[0]
#titanic_data.Ticket.value_counts()

# %%
#titanic_data.head(20)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
titanic_df['Ticket_2'] = le.fit_transform(titanic_df.Ticket)
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#              Ticket     Fare  Embarked  Ticket_2
# 0         A/5 21171   7.2500         1       523
# 1          PC 17599  71.2833         2       596
# 2  STON/O2. 3101282   7.9250         1       669
# 3            113803  53.1000         1        49
# ...

# %%
titanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    int64
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Embarked     891 non-null    int64
#  11  Ticket_2     891 non-null    int32
# dtypes: float64(2), int32(1), int64(7), object(2)
# memory usage: 80.2+ KB

# %%
titanic_df.tail(20)
# Out:
#      PassengerId  Survived  Pclass  \
# 871          872         1       1
# 872          873         0       1
# 873          874         0       3
# 874          875         1       2
# 875          876         1       3
# 876          877         0       3
# 877          878         0       3
# 878          879         0       3
# 879          880         1       1
# 880          881         1       2
# 881          882         0       3
# 882          883         0       3
# 883          884         0       2
# 884          885         0       3
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                  Name  Sex        Age  SibSp  \
# 871  Beckwith, Mrs. Richard Leonard (Sallie Monypeny)    0  47.000000      1
# ...

# %%
x = titanic_df.drop(columns =['Survived', 'Name', 'Ticket'], axis = 1)
y = titanic_df['Survived']

# %%
from sklearn.model_selection import train_test_split

# %%
# Splitting our data
x_val, x_test, y_val, y_test = train_test_split(x, y, train_size = 0.7, random_state = 40)
x_test, x_train, y_test, y_train = train_test_split(x, y, train_size = 0.7, random_state = 40)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from xgboost import XGBRegressor

# %%
lgr = LinearRegression()
dtr = DecisionTreeRegressor()
rfr = RandomForestRegressor()
gbr = GradientBoostingRegressor()
xgb = XGBRegressor()

# %%
from sklearn import metrics

# %%
models = [lgr, dtr, rfr, gbr, xgb]
for model in models:
    #fitting our model
    model.fit(x_train, y_train)
    
    #Evaluating our model
    predictions = model.predict(x_val)
    
    mae = metrics.mean_squared_error(predictions, y_val)
    rmse = metrics.mean_squared_error(predictions, y_val, squared = False)
    print(f'The {model} has a mean absolute error of {mae} and a root mean squared error of {rmse}')
# Out:
# The LinearRegression() has a mean absolute error of 0.14783630768388556 and a root mean squared error of 0.3844948734169099
# The DecisionTreeRegressor() has a mean absolute error of 0.22792937399678972 and a root mean squared error of 0.47741949478083706
# The RandomForestRegressor() has a mean absolute error of 0.13615425361155697 and a root mean squared error of 0.36899085843900925
# The GradientBoostingRegressor() has a mean absolute error of 0.133267692406386 and a root mean squared error of 0.3650584780639754
# The XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, feature_types=None, gamma=0, gpu_id=-1,
#              grow_policy='depthwise', importance_type=None,
#              interaction_constraints='', learning_rate=0.300000012, max_bin=256,
# ...

# %% [markdown]
# The best performing metric is XGBRregressor

# %%
test_df = pd.read_csv('D:/VOLUME E/DATA SCIENCE/INSIGHTS/Titanic Dataset/test.csv')
test_df.head(20)
# Out:
#     PassengerId  Pclass                                               Name  \
# 0           892       3                                   Kelly, Mr. James
# 1           893       3                   Wilkes, Mrs. James (Ellen Needs)
# 2           894       2                          Myles, Mr. Thomas Francis
# 3           895       3                                   Wirz, Mr. Albert
# 4           896       3       Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5           897       3                         Svensson, Mr. Johan Cervin
# 6           898       3                               Connolly, Miss. Kate
# 7           899       2                       Caldwell, Mr. Albert Francis
# 8           900       3          Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 9           901       3                            Davies, Mr. John Samuel
# 10          902       3                                   Ilieff, Mr. Ylio
# ...

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %%
titanic_df.describe()
# Out:
#        PassengerId    Survived      Pclass         Sex         Age  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642    0.647587   29.339313
# std     257.353842    0.486592    0.836071    0.477990   13.370271
# min       1.000000    0.000000    1.000000    0.000000    0.420000
# 25%     223.500000    0.000000    2.000000    0.000000   21.000000
# 50%     446.000000    0.000000    3.000000    1.000000   27.255814
# 75%     668.500000    1.000000    3.000000    1.000000   36.000000
# max     891.000000    1.000000    3.000000    1.000000   80.000000
#
#             SibSp       Parch        Fare    Embarked    Ticket_2
# count  891.000000  891.000000  891.000000  891.000000  891.000000
# mean     0.523008    0.381594   32.204208    1.361392  338.528620
# std      1.102743    0.806057   49.693429    0.635673  200.850657
# min      0.000000    0.000000    0.000000    1.000000    0.000000
# ...

# %%
test_df.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
test_df = test_df.drop(columns = ['Cabin'])
test_df.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Embarked
# 0  34.5      0      0   330911   7.8292        Q
# 1  47.0      1      0   363272   7.0000        S
# 2  62.0      0      0   240276   9.6875        Q
# 3  27.0      0      0   315154   8.6625        S
# 4  22.0      1      1  3101298  12.2875        S

# %%
#converting the sex into numerical values
to_map = {
    'male' : 1,
    'female' : 0
}
test_df['Sex'] = test_df['Sex'].replace(to_map)
test_df.head()
# Out:
#    PassengerId  Pclass                                          Name  Sex  \
# 0          892       3                              Kelly, Mr. James    1
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)    0
# 2          894       2                     Myles, Mr. Thomas Francis    1
# 3          895       3                              Wirz, Mr. Albert    1
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)    0
#
#     Age  SibSp  Parch   Ticket     Fare Embarked
# 0  34.5      0      0   330911   7.8292        Q
# 1  47.0      1      0   363272   7.0000        S
# 2  62.0      0      0   240276   9.6875        Q
# 3  27.0      0      0   315154   8.6625        S
# 4  22.0      1      1  3101298  12.2875        S

# %%
#Fill the missing age by mean age of Pclass, Sex and survived
col = ['Survived', 'Pclass', 'Sex']
test_df['Age'] = test_df['Age'].fillna(titanic_df.groupby(col)['Age'].transform('mean'))
test_df.head()
# Out:
#    PassengerId  Pclass                                          Name  Sex  \
# 0          892       3                              Kelly, Mr. James    1
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)    0
# 2          894       2                     Myles, Mr. Thomas Francis    1
# 3          895       3                              Wirz, Mr. Albert    1
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)    0
#
#     Age  SibSp  Parch   Ticket     Fare Embarked
# 0  34.5      0      0   330911   7.8292        Q
# 1  47.0      1      0   363272   7.0000        S
# 2  62.0      0      0   240276   9.6875        Q
# 3  27.0      0      0   315154   8.6625        S
# 4  22.0      1      1  3101298  12.2875        S

# %%
test_df.isnull().sum()
# Out:
# PassengerId    0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           1
# Embarked       0
# dtype: int64

# %%
#filling the empty values of the embarked column
test_df['Fare'].fillna(test_df['Fare'].mode()[0], inplace = True)
test_df.head()
# Out:
#    PassengerId  Pclass                                          Name  Sex  \
# 0          892       3                              Kelly, Mr. James    1
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)    0
# 2          894       2                     Myles, Mr. Thomas Francis    1
# 3          895       3                              Wirz, Mr. Albert    1
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)    0
#
#     Age  SibSp  Parch   Ticket     Fare Embarked
# 0  34.5      0      0   330911   7.8292        Q
# 1  47.0      1      0   363272   7.0000        S
# 2  62.0      0      0   240276   9.6875        Q
# 3  27.0      0      0   315154   8.6625        S
# 4  22.0      1      1  3101298  12.2875        S

# %%
test_df.isnull().sum()
# Out:
# PassengerId    0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
#Check for duplicates
test_df.duplicated().sum()
# Out:
# 0

# %%
test_df['Embarked'].nunique()
# Out:
# 3

# %%
mapping = {
    'S' : 1,
    'C' : 2,
    'Q' : 3
}
test_df['Embarked'] = test_df['Embarked'].replace(mapping)
test_df.head()
# Out:
#    PassengerId  Pclass                                          Name  Sex  \
# 0          892       3                              Kelly, Mr. James    1
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)    0
# 2          894       2                     Myles, Mr. Thomas Francis    1
# 3          895       3                              Wirz, Mr. Albert    1
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)    0
#
#     Age  SibSp  Parch   Ticket     Fare  Embarked
# 0  34.5      0      0   330911   7.8292         3
# 1  47.0      1      0   363272   7.0000         1
# 2  62.0      0      0   240276   9.6875         3
# 3  27.0      0      0   315154   8.6625         1
# 4  22.0      1      1  3101298  12.2875         1

# %%
test_df['Ticket_2'] = le.fit_transform(test_df.Ticket)
test_df.head()
# Out:
#    PassengerId  Pclass                                          Name  Sex  \
# 0          892       3                              Kelly, Mr. James    1
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)    0
# 2          894       2                     Myles, Mr. Thomas Francis    1
# 3          895       3                              Wirz, Mr. Albert    1
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)    0
#
#     Age  SibSp  Parch   Ticket     Fare  Embarked  Ticket_2
# 0  34.5      0      0   330911   7.8292         3       152
# 1  47.0      1      0   363272   7.0000         1       221
# 2  62.0      0      0   240276   9.6875         3        73
# 3  27.0      0      0   315154   8.6625         1       147
# 4  22.0      1      1  3101298  12.2875         1       138

# %%
test_df = test_df.drop(columns =['Name', 'Ticket'], axis = 1)

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Sex          418 non-null    int64
#  3   Age          418 non-null    float64
#  4   SibSp        418 non-null    int64
#  5   Parch        418 non-null    int64
#  6   Fare         418 non-null    float64
#  7   Embarked     418 non-null    int64
#  8   Ticket_2     418 non-null    int32
# dtypes: float64(2), int32(1), int64(6)
# memory usage: 27.9 KB

# %%
predictions = model.predict(test_df)
predictions
# Out:
# array([ 1.38126671e-01,  3.41123104e-01,  3.46869230e-03,  5.36559932e-02,
#         5.68578720e-01,  8.17905217e-02,  5.25484025e-01,  6.42109990e-01,
#         9.17353690e-01,  7.31696188e-02,  4.14291412e-01,  8.69402960e-02,
#         1.02298224e+00, -9.59543139e-03,  1.01963472e+00,  9.73785341e-01,
#         1.01444691e-01,  4.01105464e-01,  7.03285635e-01,  4.54949945e-01,
#         1.56806931e-01,  1.08767062e-01,  1.03840232e+00,  6.44309163e-01,
#         9.81544495e-01, -3.01593039e-02,  8.84306014e-01,  3.87248695e-01,
#         5.64489841e-01,  3.66836369e-01,  2.66280714e-02,  2.98631907e-01,
#         6.61944628e-01,  7.75437951e-01,  7.87037671e-01,  5.25209546e-01,
#         9.12948549e-01,  9.21493113e-01,  5.28648198e-02,  9.76249576e-01,
#         8.79280493e-02,  2.96791673e-01,  4.06151812e-04,  1.05263591e+00,
#         1.01994860e+00,  3.74425128e-02,  3.93559337e-01,  1.35065466e-01,
# ...

# %%
final_df = pd.DataFrame(test_df['PassengerId'])
final_df['Survived'] = predictions
final_df.to_csv("D:/VOLUME E/DATA SCIENCE/INSIGHTS/Titanic Dataset/titanic_prediction.csv", index = False)

# %%
final_df
# Out:
#      PassengerId  Survived
# 0            892  0.138127
# 1            893  0.341123
# 2            894  0.003469
# 3            895  0.053656
# 4            896  0.568579
# ..           ...       ...
# 413         1305  0.026253
# 414         1306  1.001243
# 415         1307 -0.011386
# 416         1308  0.021152
# 417         1309  0.367276
#
# [418 rows x 2 columns]
